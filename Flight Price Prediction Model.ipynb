# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\AYUSHI\Desktop\Flip Robo\Flight_Price_Prediction\Flight12_prices.csv")

# %%
df
# Out:
#              airline_name source destination date_of_journey departure_time  \
# 0                   GoAir    DEL         BOM          07-Jun          06:00
# 1                   GoAir    DEL         BOM          07-Jun          02:40
# 2                   GoAir    DEL         BOM          07-Jun          20:45
# 3                   GoAir    DEL         BOM          07-Jun          07:00
# 4           AirAsia India    DEL         BOM          07-Jun          13:00
# ...                   ...    ...         ...             ...            ...
# 1540     Hahn Air Systems    DEL         CCU          07-Jun          07:20
# 1541     Hahn Air Systems    DEL         CCU          07-Jun          13:05
# 1542   Singapore Airlines    DEL         CCU          07-Jun          09:00
# 1543     Hahn Air Systems    DEL         CCU          07-Jun          05:45
# 1544   Singapore Airlines    DEL         CCU          07-Jun          21:55
#
# ...

# %%
df.columns
# Out:
# Index(['airline_name', 'source', 'destination', 'date_of_journey',
#        'departure_time', 'arrival_time', 'duration', 'total_ s', 'route',
#        'target_variable_price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# airline_name               0
# source                     0
# destination                0
# date_of_journey            0
# departure_time             0
# arrival_time               0
# duration                   0
# total_ s                   0
# route                    379
# target_variable_price      0
# dtype: int64

# %%
df.dtypes
# Out:
# airline_name             object
# source                   object
# destination              object
# date_of_journey          object
# departure_time           object
# arrival_time             object
# duration                 object
# total_ s                  int64
# route                    object
# target_variable_price     int64
# dtype: object

# %%
df.fillna('', inplace=True)

# %%
df
# Out:
#              airline_name source destination date_of_journey departure_time  \
# 0                   GoAir    DEL         BOM          07-Jun          06:00
# 1                   GoAir    DEL         BOM          07-Jun          02:40
# 2                   GoAir    DEL         BOM          07-Jun          20:45
# 3                   GoAir    DEL         BOM          07-Jun          07:00
# 4           AirAsia India    DEL         BOM          07-Jun          13:00
# ...                   ...    ...         ...             ...            ...
# 1540     Hahn Air Systems    DEL         CCU          07-Jun          07:20
# 1541     Hahn Air Systems    DEL         CCU          07-Jun          13:05
# 1542   Singapore Airlines    DEL         CCU          07-Jun          09:00
# 1543     Hahn Air Systems    DEL         CCU          07-Jun          05:45
# 1544   Singapore Airlines    DEL         CCU          07-Jun          21:55
#
# ...

# %%
df.isnull().sum()
# Out:
# airline_name             0
# source                   0
# destination              0
# date_of_journey          0
# departure_time           0
# arrival_time             0
# duration                 0
# total_ s                 0
# route                    0
# target_variable_price    0
# dtype: int64

# %% [markdown]
# ## Visualisation of data

# %%
Columns=[]
Columns=df.columns
Columns
# Out:
# Index(['airline_name', 'source', 'destination', 'date_of_journey',
#        'departure_time', 'arrival_time', 'duration', 'total_ s', 'route',
#        'target_variable_price'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt  
for i in Columns:
    print(df[i].value_counts())
    ax=sns.countplot(x=i,data=df)
    plt.figure(figsize=(25,10))
# Out:
#  Vistara                               366
#  IndiGo                                360
#  Air India                             190
#  GoAir                                 141
#  Hahn Air Systems                      135
#  SpiceJet                              129
#  AirAsia India                         116
#  Qatar Airways                          25
#  Novaturas                              23
#  Emirates                               18
#  Singapore Airlines                      9
#  Vistara + Qatar Airways                 8
#  Flexflight                              7
#  Qatar Airways + Vistara                 6
#  Alliance Air                            2
#  IndiGo + Vistara                        2
#  SriLankan Airlines                      2
#  Qatar Airways + SriLankan Airlines      1
#  Oman Air                                1
# Qatar Airways                            1
#  IndiGo                                  1
#  Air India                               1
# ...

# %% [markdown]
# ### To encode catogorical variable or object data type to quantitative variable or numbers

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       airline_name  source  destination  date_of_journey  departure_time  \
# 0              7.0     2.0          1.0              0.0            35.0
# 1              7.0     2.0          1.0              0.0            10.0
# 2              7.0     2.0          1.0              0.0           204.0
# 3              7.0     2.0          1.0              0.0            47.0
# 4              2.0     2.0          1.0              0.0           115.0
# ...            ...     ...          ...              ...             ...
# 1540           8.0     2.0          2.0              0.0            51.0
# 1541           8.0     2.0          2.0              0.0           116.0
# 1542          17.0     2.0          2.0              0.0            69.0
# 1543           8.0     2.0          2.0              0.0            32.0
# 1544          17.0     2.0          2.0              0.0           218.0
#
#       arrival_time  duration  total_ s  route  target_variable_price
# ...

# %%
df1=df.drop("date_of_journey",axis=1)

# %%
df1
# Out:
#       airline_name  source  destination  departure_time  arrival_time  \
# 0              7.0     2.0          1.0            35.0          67.0
# 1              7.0     2.0          1.0            10.0          41.0
# 2              7.0     2.0          1.0           204.0         239.0
# 3              7.0     2.0          1.0            47.0          80.0
# 4              2.0     2.0          1.0           115.0         145.0
# ...            ...     ...          ...             ...           ...
# 1540           8.0     2.0          2.0            51.0         247.0
# 1541           8.0     2.0          2.0           116.0         125.0
# 1542          17.0     2.0          2.0            69.0         235.0
# 1543           8.0     2.0          2.0            32.0         247.0
# 1544          17.0     2.0          2.0           218.0         235.0
#
#       duration  total_ s  route  target_variable_price
# 0        187.0         0    0.0                   5460
# ...

# %%
df1.corr()
# Out:
#                        airline_name    source  destination  departure_time  \
# airline_name               1.000000 -0.012034     0.019021        0.022284
# source                    -0.012034  1.000000     0.112389       -0.005379
# destination                0.019021  0.112389     1.000000        0.025568
# departure_time             0.022284 -0.005379     0.025568        1.000000
# arrival_time               0.051190  0.049896     0.010938       -0.036133
# duration                  -0.037231 -0.045866    -0.027582       -0.068775
# total_ s                  -0.009522  0.040513     0.048105       -0.078338
# route                     -0.089889 -0.039903    -0.090886       -0.129093
# target_variable_price      0.057139  0.079861     0.018346       -0.125522
#
#                        arrival_time  duration  total_ s     route  \
# airline_name               0.051190 -0.037231 -0.009522 -0.089889
# source                     0.049896 -0.045866  0.040513 -0.039903
# ...

# %%
df1.corr()['target_variable_price'].sort_values(ascending=False)
# Out:
# target_variable_price    1.000000
# total_ s                 0.422928
# route                    0.225330
# source                   0.079861
# airline_name             0.057139
# destination              0.018346
# arrival_time            -0.025582
# departure_time          -0.125522
# duration                -0.249817
# Name: target_variable_price, dtype: float64

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#        airline_name       source  destination  departure_time  arrival_time  \
# count   1545.000000  1545.000000  1545.000000     1545.000000   1545.000000
# mean      10.671845     1.492557     2.585761      115.914563    145.440129
# std        7.014725     0.869073     1.825071       65.391362     71.363927
# min        0.000000     0.000000     0.000000        0.000000      0.000000
# 25%        7.000000     1.000000     1.000000       54.000000     81.000000
# 50%        9.000000     2.000000     3.000000      112.000000    156.000000
# 75%       18.000000     2.000000     4.000000      174.000000    207.000000
# max       22.000000     4.000000     7.000000      235.000000    251.000000
#
#           duration     total_ s        route  target_variable_price
# count  1545.000000  1545.000000  1545.000000            1545.000000
# mean    164.968285     0.899029    48.201294           17565.996117
# std      86.747487     0.622468    46.153175           16585.935065
# ...

# %%
x=df1.drop("target_variable_price",axis=1)
y=df1["target_variable_price"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# route             0.547572
# destination       0.460741
# total_ s          0.168879
# departure_time    0.098604
# airline_name      0.074709
# arrival_time     -0.297024
# source           -0.439485
# duration         -0.562106
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#       airline_name    source  destination  departure_time  arrival_time  \
# 0        -0.403071  0.561159    -0.828249       -1.290619     -1.087853
# 1        -0.403071  0.561159    -0.828249       -1.961502     -1.472957
# 2        -0.403071  0.561159    -0.828249        1.256319      1.287803
# 3        -0.403071  0.561159    -0.828249       -1.036957     -0.899551
# 4        -1.264115  0.561159    -0.828249        0.102148      0.014940
# ...            ...       ...          ...             ...           ...
# 1540     -0.255692  0.561159    -0.177086       -0.957785      1.394250
# 1541     -0.255692  0.561159    -0.177086        0.116643     -0.262549
# 1542      0.896372  0.561159    -0.177086       -0.626095      1.234486
# 1543     -0.255692  0.561159    -0.177086       -1.358690      1.394250
# 1544      0.896372  0.561159    -0.177086        1.419127      1.234486
#
#       duration  total_ s     route
# 0     0.254555 -1.496261 -1.411111
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# total_ s         -0.048884
# destination      -0.074052
# source           -0.120068
# departure_time   -0.191935
# airline_name     -0.261621
# route            -0.276629
# arrival_time     -0.362119
# duration         -0.563443
# dtype: float64

# %%
sk=x.skew()

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# airline_name       True
# source            False
# destination        True
# departure_time     True
# arrival_time       True
# duration           True
# total_ s          False
# route              True
# dtype: bool

# %%
new_df=pd.concat([x,y],axis=1)
new_df
# Out:
#       airline_name    source  destination  departure_time  arrival_time  \
# 0        -0.403071  0.561159    -0.828249       -1.290619     -1.087853
# 1        -0.403071  0.561159    -0.828249       -1.961502     -1.472957
# 2        -0.403071  0.561159    -0.828249        1.256319      1.287803
# 3        -0.403071  0.561159    -0.828249       -1.036957     -0.899551
# 4        -1.264115  0.561159    -0.828249        0.102148      0.014940
# ...            ...       ...          ...             ...           ...
# 1540     -0.255692  0.561159    -0.177086       -0.957785      1.394250
# 1541     -0.255692  0.561159    -0.177086        0.116643     -0.262549
# 1542      0.896372  0.561159    -0.177086       -0.626095      1.234486
# 1543     -0.255692  0.561159    -0.177086       -1.358690      1.394250
# 1544      0.896372  0.561159    -0.177086        1.419127      1.234486
#
#       duration  total_ s     route  target_variable_price
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(new_df))
new_df=new_df[(z<3).all(axis=1)]

# %%
x=new_df.drop("target_variable_price",axis=1)
y=new_df["target_variable_price"]

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x
# Out:
#       airline_name    source  destination  departure_time  arrival_time  \
# 0        -0.403071  0.561159    -0.828249       -1.290619     -1.087853
# 1        -0.403071  0.561159    -0.828249       -1.961502     -1.472957
# 2        -0.403071  0.561159    -0.828249        1.256319      1.287803
# 3        -0.403071  0.561159    -0.828249       -1.036957     -0.899551
# 4        -1.264115  0.561159    -0.828249        0.102148      0.014940
# ...            ...       ...          ...             ...           ...
# 1537     -0.255692  0.561159    -0.177086        0.942637     -0.899551
# 1539     -1.742825  0.561159    -0.177086       -0.522780     -0.178992
# 1540     -0.255692  0.561159    -0.177086       -0.957785      1.394250
# 1541     -0.255692  0.561159    -0.177086        0.116643     -0.262549
# 1544      0.896372  0.561159    -0.177086        1.419127      1.234486
#
#       duration  total_ s     route
# 0     0.254555 -1.496261 -1.411111
# ...

# %%
y
# Out:
# 0        5460
# 1        5460
# 2        5460
# 3        5460
# 4        6918
#         ...
# 1537    59513
# 1539    33002
# 1540    60537
# 1541    40950
# 1544    66095
# Name: target_variable_price, Length: 1467, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,1000) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.18088272606500977
# at random state 0,the testing accuracy is :0.1512274165908405
#
#
# at random state 1,the training accuracy is :0.1823321596325811
# at random state 1,the testing accuracy is :0.13857578857579644
#
#
# at random state 2,the training accuracy is :0.17007625075992516
# at random state 2,the testing accuracy is :0.1887313448970186
#
#
# at random state 3,the training accuracy is :0.1955764050140839
# at random state 3,the testing accuracy is :0.09920302423106542
#
#
# at random state 4,the training accuracy is :0.1788532655950017
# at random state 4,the testing accuracy is :0.15193067046637043
#
#
# at random state 5,the training accuracy is :0.1803343471832496
# at random state 5,the testing accuracy is :0.15454134264729757
#
#
# at random state 6,the training accuracy is :0.17992653031454597
# at random state 6,the testing accuracy is :0.15688540434929243
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=)

# %%
x_train.shape
# Out:
# (1173, 8)

# %%
y_train.shape
# Out:
# (1173,)

# %%
x_test.shape
# Out:
# (294, 8)

# %%
y_test.shape
# Out:
# (294,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.17747877028269887

# %% [markdown]
# ## CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.09598941252090559 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# At cross fold 3 the cv score is 0.13027677671874952 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# At cross fold 4 the cv score is 0.12883922496423159 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# At cross fold 5 the cv score is 0.11730446099862095 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# At cross fold 6 the cv score is 0.12165424679742785 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# At cross fold 7 the cv score is 0.11617600939959472 and accuracy score for training is -0.2002703703136668and accuracy score for testing is 0.17747877028269887
#
#
# ...

# %% [markdown]
# ## Plot the Data

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.1774786566663632

# %%
cv_score=cross_val_score(ls,x,y,cv=2)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.0969372250304964

# %% [markdown]
# ## Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)


rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=2)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 score: 79.07587638638779
# Cross Val Score: 59.78715333796458

# %% [markdown]
# ## we are getting our model accuracy around 80% and cross validation around 60 % which shows our model is performing good but there is overfitting as there is less data and also the data can be captured in a better way

# %%
import pickle

# %%
filename='Flight_Price_Prediction.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model= pickle.load(open('Flight_Price_Prediction.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.7907587638638779

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion
# Out:
#                 0         1         2         3        4         5    \
# predicted  10196.62  14513.86  12500.77  44277.14  7791.91  10249.53
# original   10196.62  14513.86  12500.77  44277.14  7791.91  10249.53
#
#                 6         7         8        9    ...       284      285  \
# predicted  17071.33  20135.99  15918.29  8476.36  ...  10340.71  8143.64
# original   17071.33  20135.99  15918.29  8476.36  ...  10340.71  8143.64
#
#                 286       287       288      289     290       291      292  \
# predicted  14602.46  18162.22  18154.44  17433.0  7454.3  14838.52  8914.66
# original   14602.46  18162.22  18154.44  17433.0  7454.3  14838.52  8914.66
#
#                293
# predicted  9965.69
# original   9965.69
#
# [2 rows x 294 columns]
